# %%
import numpy as np
import pandas as pd
import nltk
from fuzzywuzzy import fuzz
from nltk.metrics import jaccard_distance
from numpy import save
import itertools
# Out:
# /home/ig5eq/.local/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
ndc = pd.read_csv("../data/working/ndc_clean.csv", index_col = [0])

# %%
len(ndc)
# Out:
# 7023

# %%
ndc.tail(10)
# Out:
#                            original_company  originalRow  \
# row
# 7013                              Zoono USA         7038
# 7014                         ZOONO USA, LLC         7039
# 7015                        ZRG DETOX, INC.         7040
# 7016  Zunyi Jici Bio-Health Products Co Ltd         7041
# 7017       Zydus Pharmaceuticals (USA) Inc.         7042
# 7018          Zydus Pharmaceuticals USA Inc         7043
# 7019         Zydus Pharmaceuticals USA Inc.         7044
# 7020             Zydus Technologies Limited         7045
# 7021                                 ZYGONE         7046
# 7022             Zyla Life Sciences US Inc.         7047
#
#                cleaned_name
# row
# 7013                  zoono
# 7014                  zoono
# 7015              zrg detox
# 7016  zunyi jici bio-health
# 7017                  zydus
# 7018                  zydus
# 7019                  zydus
# 7020                  zydus
# 7021                 zygone
# 7022     zyla life sciences

# %%
ndc.dropna(inplace = True)
ndc.reset_index(inplace = True)

# %%
ndc.tail(5)
# Out:
#        row                original_company  originalRow        cleaned_name
# 6712  7018   Zydus Pharmaceuticals USA Inc         7043               zydus
# 6713  7019  Zydus Pharmaceuticals USA Inc.         7044               zydus
# 6714  7020      Zydus Technologies Limited         7045               zydus
# 6715  7021                          ZYGONE         7046              zygone
# 6716  7022      Zyla Life Sciences US Inc.         7047  zyla life sciences

# %%
ndc_row = ndc['row']

# %%
ndc_org = ndc['original_company']

# %%
ndc_clean = ndc['cleaned_name']

# %%
fda = pd.read_csv("../data/working/fda_clean.csv", index_col = [0])

# %%
fda.dropna(inplace = True)
fda.reset_index(inplace = True)

# %%
fda.columns
# Out:
# Index(['index', 'FDA Companies ', 'Company Clean'], dtype='object')

# %%
fda_row = fda['index']

# %%
fda_og = fda['FDA Companies ']

# %%
fda_clean = fda['Company Clean']

# %%
##Function that takes in 3 lists, the list of strings you want to compare, the list of strings you're comparing to and a list with the original way the string from list 1 was written.  
def matchWithFuzzyNamesOG(l1, l2, og1, og2, row_num1, row_num2):
    match = pd.DataFrame(columns = ['clean fda company name', 'original fda company', 'fda row', 'clean ndc row', 'clean ndc company', 'original ndc company', 'fuzz ratio'])
    for (i, o, r) in zip(l1, og1, row_num1):
        matches = []
        score = []
        #score_partial = []
        row = []
        matchesog = []
        for (j, q, s) in zip(l2, og2, row_num2):
            #due to time constraints, we set the fuzz.ratio to 100, however future programming should adjust this value to some other quantity to see if we get better matches
            if (fuzz.ratio(i,j)) == 100:
                matches.append(j)
                matchesog.append(q)
                score.append(fuzz.ratio(i,j))
                row.append(s)
                #the partial ratio will return the ratio raw score of 100  if the shorter string is found an any of substrings of the larger string, used this as a safety net and potentially as an additional step to 
               # score_partial.append((fuzz.partial_ratio(i,j)))
                match = match.append({ 'clean fda company name': i, 'original fda company': o, 'fda row': r, 'clean ndc row': row, 'clean ndc company': matches,   'original ndc company': matchesog, 'fuzz ratio': score,},ignore_index=True)
        
#Will output a pandas dataframe with 4 columns
    return match

# %%
fda_og.head(10)
# Out:
# 0         3D IMAGING DRUG
# 1                      3M
# 2        3M DRUG DELIVERY
# 3           AAIPHARMA LLC
# 4             ABBOTT LABS
# 5                  ABBVIE
# 6        ABBVIE ENDOCRINE
# 7    ABBVIE ENDOCRINE INC
# 8              ABBVIE INC
# 9               ABHAI INC
# Name: FDA Companies , dtype: object

# %%
matchWithFuzzyNamesOG(fda_clean, ndc_clean, fda_og, ndc_org, fda_row, ndc_row)
# Out:
#     clean fda company name  original fda company fda row  \
# 0           d imaging drug       3D IMAGING DRUG       0
# 1                        m                    3M       1
# 2          m drug delivery      3M DRUG DELIVERY       2
# 3                aaipharma         AAIPHARMA LLC       3
# 4                   abbott           ABBOTT LABS       4
# ..                     ...                   ...     ...
# 968                zo skin        ZO SKIN HEALTH     970
# 969                  zydus        ZYDUS HLTHCARE     971
# 970                  zydus      ZYDUS PHARMS USA     972
# 971                  zydus  ZYDUS PHARMS USA INC     973
# 972        zydus worldwide       ZYDUS WORLDWIDE     974
#
#                 clean ndc row             clean ndc company  \
# 0                          []                            []
# 1                    [20, 22]                        [m, m]
# 2                          []                            []
# 3                          []                            []
# 4                          []                            []
# ..                        ...                           ...
# 968                    [7009]                     [zo skin]
# 969  [7017, 7018, 7019, 7020]  [zydus, zydus, zydus, zydus]
# 970  [7017, 7018, 7019, 7020]  [zydus, zydus, zydus, zydus]
# 971  [7017, 7018, 7019, 7020]  [zydus, zydus, zydus, zydus]
# 972                        []                            []
#
#                                   original ndc company            fuzz ratio
# 0                                                   []                    []
# 1                         [3M Company, 3M Health Care]            [100, 100]
# 2                                                   []                    []
# 3                                                   []                    []
# 4                                                   []                    []
# ..                                                 ...                   ...
# 968                             [ZO Skin Health, Inc.]                 [100]
# 969  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...  [100, 100, 100, 100]
# 970  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...  [100, 100, 100, 100]
# 971  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...  [100, 100, 100, 100]
# 972                                                 []                    []
#
# [973 rows x 7 columns]

# %%
fdc_match = matchWithFuzzyNamesOG(fda_clean, ndc_clean, fda_og, ndc_org, fda_row, ndc_row)

# %%
fdc_match
# Out:
#     clean fda company name  original fda company fda row  \
# 0                        m                    3M       1
# 2                   abbvie                ABBVIE       5
# 3                   abbvie            ABBVIE INC       8
# 4       abraxis bioscience    ABRAXIS BIOSCIENCE      11
# 5                   accord       ACCORD HLTHCARE      12
# ..                     ...                   ...     ...
# 913              yaopharma      YAOPHARMA CO LTD     966
# 914                zo skin        ZO SKIN HEALTH     970
# 915                  zydus        ZYDUS HLTHCARE     971
# 919                  zydus      ZYDUS PHARMS USA     972
# 923                  zydus  ZYDUS PHARMS USA INC     973
#
#                 clean ndc row                         clean ndc company  \
# 0                    [20, 22]                                    [m, m]
# 2                        [66]                                  [abbvie]
# 3                        [66]                                  [abbvie]
# 4                        [71]                      [abraxis bioscience]
# 5        [81, 82, 83, 84, 85]  [accord, accord, accord, accord, accord]
# ..                        ...                                       ...
# 913                    [6939]                               [yaopharma]
# 914                    [7009]                                 [zo skin]
# 915  [7017, 7018, 7019, 7020]              [zydus, zydus, zydus, zydus]
# 919  [7017, 7018, 7019, 7020]              [zydus, zydus, zydus, zydus]
# 923  [7017, 7018, 7019, 7020]              [zydus, zydus, zydus, zydus]
#
#                                   original ndc company  \
# 0                         [3M Company, 3M Health Care]
# 2                                        [AbbVie Inc.]
# 3                                        [AbbVie Inc.]
# 4                            [Abraxis BioScience, LLC]
# 5    [Accord Healthcare, Accord Healthcare Inc, Acc...
# ..                                                 ...
# 913                              [Yaopharma Co., Ltd.]
# 914                             [ZO Skin Health, Inc.]
# 915  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...
# 919  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...
# 923  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...
#
#                     fuzz ratio
# 0                   [100, 100]
# 2                        [100]
# 3                        [100]
# 4                        [100]
# 5    [100, 100, 100, 100, 100]
# ..                         ...
# 913                      [100]
# 914                      [100]
# 915       [100, 100, 100, 100]
# 919       [100, 100, 100, 100]
# 923       [100, 100, 100, 100]
#
# [490 rows x 7 columns]

# %%
fdc_match = fdc_match[~fdc_match.duplicated('fda row')]

# %%
fdc_match['clean fda company name'] = fdc_match['clean fda company name'].astype(str)
fdc_match['original fda company'] = fdc_match['original fda company'].astype(str)
fdc_match['fda row'] = fdc_match['fda row'].astype(str)

# %%
#ndc_unique = fdc_match[~fdc_match.duplicated('clean ndc company')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-38d543b6ed63> in <module>
# ----> 1 ndc_unique = fdc_match[~fdc_match.duplicated('clean ndc company')]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
# -> 4888         labels, shape = map(list, zip(*map(f, vals)))
#    4889
#    4890         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in f(vals)
#    4861         def f(vals):
#    4862             labels, shape = algorithms.factorize(
# -> 4863                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT)
#    4864             )
#    4865             return labels.astype("i8", copy=False), len(shape)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     634
#     635         codes, uniques = _factorize_array(
# --> 636             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     637         )
#     638
#
# ~/.local/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     482
#     483     table = hash_klass(size_hint or len(values))
# --> 484     uniques, codes = table.factorize(values, na_sentinel=na_sentinel, na_value=na_value)
#     485
#     486     codes = ensure_platform_int(codes)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
#ndc_unique = fdc_match.drop_duplicates(subset='clean ndc company')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-070e93875342> in <module>
# ----> 1 ndc_unique = fdc_match.drop_duplicates(subset='clean ndc company')
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace, ignore_index)
#    4809
#    4810         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 4811         duplicated = self.duplicated(subset, keep=keep)
#    4812
#    4813         if inplace:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    4886
#    4887         vals = (col.values for name, col in self.items() if name in subset)
# -> 4888         labels, shape = map(list, zip(*map(f, vals)))
#    4889
#    4890         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in f(vals)
#    4861         def f(vals):
#    4862             labels, shape = algorithms.factorize(
# -> 4863                 vals, size_hint=min(len(self), _SIZE_HINT_LIMIT)
#    4864             )
#    4865             return labels.astype("i8", copy=False), len(shape)
#
# ~/.local/lib/python3.7/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     634
#     635         codes, uniques = _factorize_array(
# --> 636             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     637         )
#     638
#
# ~/.local/lib/python3.7/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value)
#     482
#     483     table = hash_klass(size_hint or len(values))
# --> 484     uniques, codes = table.factorize(values, na_sentinel=na_sentinel, na_value=na_value)
#     485
#     486     codes = ensure_platform_int(codes)
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
fdc_unique = fdc_match.groupby('clean fda company name', as_index = False).agg({'original fda company': ', '.join, 
                                                                            'fda row': ', '.join
                                                                                })

# %%
fdc_unique1 = fdc_match.groupby('clean fda company name', as_index = False).first()

# %%
fdc_unique1
# Out:
#     clean fda company name original fda company fda row  \
# 0                   abbvie               ABBVIE       5
# 1       abraxis bioscience   ABRAXIS BIOSCIENCE      11
# 2                   accord      ACCORD HLTHCARE      12
# 3                      aci   ACI HEALTHCARE LTD      15
# 4                  actavis          ACTAVIS INC      25
# ..                     ...                  ...     ...
# 351                 xspire        XSPIRE PHARMA     963
# 352                xttrium              XTTRIUM     964
# 353              yaopharma     YAOPHARMA CO LTD     966
# 354                zo skin       ZO SKIN HEALTH     970
# 355                  zydus       ZYDUS HLTHCARE     971
#
#                 clean ndc row                         clean ndc company  \
# 0                        [66]                                  [abbvie]
# 1                        [71]                      [abraxis bioscience]
# 2        [81, 82, 83, 84, 85]  [accord, accord, accord, accord, accord]
# 3                        [98]                                     [aci]
# 4                  [108, 109]                        [actavis, actavis]
# ..                        ...                                       ...
# 351        [6925, 6926, 6927]                  [xspire, xspire, xspire]
# 352                    [6928]                                 [xttrium]
# 353                    [6939]                               [yaopharma]
# 354                    [7009]                                 [zo skin]
# 355  [7017, 7018, 7019, 7020]              [zydus, zydus, zydus, zydus]
#
#                                   original ndc company  \
# 0                                        [AbbVie Inc.]
# 1                            [Abraxis BioScience, LLC]
# 2    [Accord Healthcare, Accord Healthcare Inc, Acc...
# 3                           [ACI Healthcare USA, Inc.]
# 4          [Actavis Pharma, Inc, Actavis Pharma, Inc.]
# ..                                                 ...
# 351  [Xspire Pharma, Xspire Pharma LLC, Xspire Phar...
# 352                       [Xttrium Laboratories, Inc.]
# 353                              [Yaopharma Co., Ltd.]
# 354                             [ZO Skin Health, Inc.]
# 355  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...
#
#                     fuzz ratio
# 0                        [100]
# 1                        [100]
# 2    [100, 100, 100, 100, 100]
# 3                        [100]
# 4                   [100, 100]
# ..                         ...
# 351            [100, 100, 100]
# 352                      [100]
# 353                      [100]
# 354                      [100]
# 355       [100, 100, 100, 100]
#
# [356 rows x 7 columns]

# %%
fdc_unique[['corporate family', 'clean ndc row', 'clean ndc company', 'original ndc company', 'fuzz ratio']] = fdc_unique1[['clean fda company name','clean ndc row', 'clean ndc company', 'original ndc company', 'fuzz ratio']]

# %%
fdc_uni
# Out:
#     clean fda company name                               original fda company  \
# 0                   abbvie                                 ABBVIE, ABBVIE INC
# 1       abraxis bioscience                                 ABRAXIS BIOSCIENCE
# 2                   accord               ACCORD HLTHCARE, ACCORD HLTHCARE INC
# 3                      aci                                 ACI HEALTHCARE LTD
# 4                  actavis           ACTAVIS INC, ACTAVIS LLC, ACTAVIS PHARMA
# ..                     ...                                                ...
# 351                 xspire                                      XSPIRE PHARMA
# 352                xttrium                                            XTTRIUM
# 353              yaopharma                                   YAOPHARMA CO LTD
# 354                zo skin                                     ZO SKIN HEALTH
# 355                  zydus  ZYDUS HLTHCARE, ZYDUS PHARMS USA, ZYDUS PHARMS...
#
#            fda row             clean ndc row  \
# 0             5, 8                      [66]
# 1               11                      [71]
# 2           12, 13      [81, 82, 83, 84, 85]
# 3               15                      [98]
# 4       25, 30, 32                [108, 109]
# ..             ...                       ...
# 351            963        [6925, 6926, 6927]
# 352            964                    [6928]
# 353            966                    [6939]
# 354            970                    [7009]
# 355  971, 972, 973  [7017, 7018, 7019, 7020]
#
#                             clean ndc company  \
# 0                                    [abbvie]
# 1                        [abraxis bioscience]
# 2    [accord, accord, accord, accord, accord]
# 3                                       [aci]
# 4                          [actavis, actavis]
# ..                                        ...
# 351                  [xspire, xspire, xspire]
# 352                                 [xttrium]
# 353                               [yaopharma]
# 354                                 [zo skin]
# 355              [zydus, zydus, zydus, zydus]
#
#                                   original ndc company  \
# 0                                        [AbbVie Inc.]
# 1                            [Abraxis BioScience, LLC]
# 2    [Accord Healthcare, Accord Healthcare Inc, Acc...
# 3                           [ACI Healthcare USA, Inc.]
# 4          [Actavis Pharma, Inc, Actavis Pharma, Inc.]
# ..                                                 ...
# 351  [Xspire Pharma, Xspire Pharma LLC, Xspire Phar...
# 352                       [Xttrium Laboratories, Inc.]
# 353                              [Yaopharma Co., Ltd.]
# 354                             [ZO Skin Health, Inc.]
# 355  [Zydus Pharmaceuticals (USA) Inc., Zydus Pharm...
#
#                     fuzz ratio    corporate family
# 0                        [100]              abbvie
# 1                        [100]  abraxis bioscience
# 2    [100, 100, 100, 100, 100]              accord
# 3                        [100]                 aci
# 4                   [100, 100]             actavis
# ..                         ...                 ...
# 351            [100, 100, 100]              xspire
# 352                      [100]             xttrium
# 353                      [100]           yaopharma
# 354                      [100]             zo skin
# 355       [100, 100, 100, 100]               zydus
#
# [356 rows x 8 columns]

# %% [markdown]
# ## DNA

# %%
dna = pd.read_csv("../data/working/dna_clean.csv", index_col = [0])

# %%
dna.dropna(inplace = True)
dna.reset_index(inplace = True)

# %%
dna.head(4)
# Out:
#    index  Unnamed: 0.1    Code  \
# 0      0             0      AA
# 1      1             2  AAAADJ
# 2      2             3  AAAAIY
# 3      3             5  AAABBB
#
#                                          Description  \
# 0                                             AA PLC
# 1                            Emperial Americas, Inc.
# 2  American Academy of Allergy, Asthma and Immuno...
# 3                                Bird Studies Canada
#
#                    cleaned_companies
# 0                                 aa
# 1                  emperial americas
# 2  academy allergy asthma immunology
# 3                bird studies canada

# %%
dna_row = dna['index']
dna_org = dna['Description']
dna_clean = dna['cleaned_companies']

# %%
dnf_match = matchWithFuzzyNamesOG(fda_clean, dna_clean, fda_og, dna_org, fda_row, dna_row)

# %%
dnf_match.to_csv('DNA and FDA matches')

# %%
dnf_match = pd.read_csv('DNA and FDA matches')

# %%
dnf_match
# Out:
#      Unnamed: 0 clean fda company name original fda company  fda row  \
# 0             0                      m                   3M        1
# 1             1                      m                   3M        1
# 2             2                      m                   3M        1
# 3             3                      m                   3M        1
# 4             4                      m                   3M        1
# ..          ...                    ...                  ...      ...
# 613         613              wockhardt        WOCKHARDT LTD      953
# 614         614              wockhardt        WOCKHARDT USA      954
# 615         615                  wyeth     WYETH PHARMS INC      957
# 616         616                  wyeth     WYETH PHARMS INC      957
# 617         617                 zambon           ZAMBON SPA      968
#
#                                   clean ndc row  \
# 0    [33223, 37340, 38604, 53031, 56261, 58045]
# 1    [33223, 37340, 38604, 53031, 56261, 58045]
# 2    [33223, 37340, 38604, 53031, 56261, 58045]
# 3    [33223, 37340, 38604, 53031, 56261, 58045]
# 4    [33223, 37340, 38604, 53031, 56261, 58045]
# ..                                          ...
# 613                                     [61416]
# 614                                     [61416]
# 615                               [1808, 15691]
# 616                               [1808, 15691]
# 617                                     [63778]
#
#                   clean ndc company  \
# 0    ['m', 'm', 'm', 'm', 'm', 'm']
# 1    ['m', 'm', 'm', 'm', 'm', 'm']
# 2    ['m', 'm', 'm', 'm', 'm', 'm']
# 3    ['m', 'm', 'm', 'm', 'm', 'm']
# 4    ['m', 'm', 'm', 'm', 'm', 'm']
# ..                              ...
# 613                   ['wockhardt']
# 614                   ['wockhardt']
# 615              ['wyeth', 'wyeth']
# 616              ['wyeth', 'wyeth']
# 617                      ['zambon']
#
#                                   original ndc company  \
# 0    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# 1    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# 2    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# 3    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# 4    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# ..                                                 ...
# 613                                  ['Wockhardt Ltd']
# 614                                  ['Wockhardt Ltd']
# 615                        ['Wyeth LLC', 'Wyeth Ltd.']
# 616                        ['Wyeth LLC', 'Wyeth Ltd.']
# 617                             ['Zambon Company SpA']
#
#                          fuzz ratio
# 0    [100, 100, 100, 100, 100, 100]
# 1    [100, 100, 100, 100, 100, 100]
# 2    [100, 100, 100, 100, 100, 100]
# 3    [100, 100, 100, 100, 100, 100]
# 4    [100, 100, 100, 100, 100, 100]
# ..                              ...
# 613                           [100]
# 614                           [100]
# 615                      [100, 100]
# 616                      [100, 100]
# 617                           [100]
#
# [618 rows x 8 columns]

# %%
dnf_match = dnf_match[~dnf_match.duplicated('fda row')]

# %%
dnf_match
# Out:
#      Unnamed: 0 clean fda company name original fda company  fda row  \
# 0             0                      m                   3M        1
# 6             6              aaipharma        AAIPHARMA LLC        3
# 7             7                 abbott          ABBOTT LABS        4
# 10           10                 abbvie               ABBVIE        5
# 11           11                 abbvie           ABBVIE INC        8
# ..          ...                    ...                  ...      ...
# 612         612          wockhardt bio     WOCKHARDT BIO AG      952
# 613         613              wockhardt        WOCKHARDT LTD      953
# 614         614              wockhardt        WOCKHARDT USA      954
# 615         615                  wyeth     WYETH PHARMS INC      957
# 617         617                 zambon           ZAMBON SPA      968
#
#                                   clean ndc row  \
# 0    [33223, 37340, 38604, 53031, 56261, 58045]
# 6                                        [3820]
# 7                               [260, 273, 275]
# 10                                        [488]
# 11                                        [488]
# ..                                          ...
# 612                                     [62283]
# 613                                     [61416]
# 614                                     [61416]
# 615                               [1808, 15691]
# 617                                     [63778]
#
#                   clean ndc company  \
# 0    ['m', 'm', 'm', 'm', 'm', 'm']
# 6                     ['aaipharma']
# 7    ['abbott', 'abbott', 'abbott']
# 10                       ['abbvie']
# 11                       ['abbvie']
# ..                              ...
# 612               ['wockhardt bio']
# 613                   ['wockhardt']
# 614                   ['wockhardt']
# 615              ['wyeth', 'wyeth']
# 617                      ['zambon']
#
#                                   original ndc company  \
# 0    ['M101 Corp', '3M Company', 'M2 Group Ltd.', '...
# 6                         ['AAIPharma Services Corp.']
# 7             ['Abbott AG', 'Abbott Oy', 'Abbott Srl']
# 10                                     ['AbbVie Inc.']
# 11                                     ['AbbVie Inc.']
# ..                                                 ...
# 612                               ['Wockhardt Bio AG']
# 613                                  ['Wockhardt Ltd']
# 614                                  ['Wockhardt Ltd']
# 615                        ['Wyeth LLC', 'Wyeth Ltd.']
# 617                             ['Zambon Company SpA']
#
#                          fuzz ratio
# 0    [100, 100, 100, 100, 100, 100]
# 6                             [100]
# 7                   [100, 100, 100]
# 10                            [100]
# 11                            [100]
# ..                              ...
# 612                           [100]
# 613                           [100]
# 614                           [100]
# 615                      [100, 100]
# 617                           [100]
#
# [327 rows x 8 columns]

# %%
dnf_match['clean fda company name'] = dnf_match['clean fda company name'].astype(str)
dnf_match['original fda company'] = dnf_match['original fda company'].astype(str)
dnf_match['fda row'] = dnf_match['fda row'].astype(str)

# %%
dnf_match_unique = dnf_match.groupby('clean fda company name', as_index = False).agg({'original fda company': ', '.join, 
                                                                            'fda row': ', '.join
                                                                                })

# %%
dnf_match1 = dnf_match.groupby('clean fda company name', as_index = False).first()

# %%
dnf_match1
# Out:
#     clean fda company name  Unnamed: 0 original fda company fda row  \
# 0                aaipharma           6        AAIPHARMA LLC       3
# 1                   abbott           7          ABBOTT LABS       4
# 2                   abbvie          10               ABBVIE       5
# 3       abraxis bioscience          12   ABRAXIS BIOSCIENCE      11
# 4                      aci          13   ACI HEALTHCARE LTD      15
# ..                     ...         ...                  ...     ...
# 234               wilshire         609  WILSHIRE PHARMS INC     948
# 235              wockhardt         611            WOCKHARDT     951
# 236          wockhardt bio         612     WOCKHARDT BIO AG     952
# 237                  wyeth         615     WYETH PHARMS INC     957
# 238                 zambon         617           ZAMBON SPA     968
#
#        clean ndc row               clean ndc company  \
# 0             [3820]                   ['aaipharma']
# 1    [260, 273, 275]  ['abbott', 'abbott', 'abbott']
# 2              [488]                      ['abbvie']
# 3             [3198]          ['abraxis bioscience']
# 4         [699, 700]                  ['aci', 'aci']
# ..               ...                             ...
# 234   [61913, 61915]        ['wilshire', 'wilshire']
# 235          [61416]                   ['wockhardt']
# 236          [62283]               ['wockhardt bio']
# 237    [1808, 15691]              ['wyeth', 'wyeth']
# 238          [63778]                      ['zambon']
#
#                                original ndc company       fuzz ratio
# 0                      ['AAIPharma Services Corp.']            [100]
# 1          ['Abbott AG', 'Abbott Oy', 'Abbott Srl']  [100, 100, 100]
# 2                                   ['AbbVie Inc.']            [100]
# 3                      ['Abraxis BioScience, Inc.']            [100]
# 4              ['ACI International', 'ACI Limited']       [100, 100]
# ..                                              ...              ...
# 234  ['Wilshire Bank', 'Wilshire Technologies Inc']       [100, 100]
# 235                               ['Wockhardt Ltd']            [100]
# 236                            ['Wockhardt Bio AG']            [100]
# 237                     ['Wyeth LLC', 'Wyeth Ltd.']       [100, 100]
# 238                          ['Zambon Company SpA']            [100]
#
# [239 rows x 8 columns]

# %%
dnf_match_unique[['corporate family', 'clean dna row', 'clean dna company', 'original dna company', 'fuzz ratio']] = dnf_match1[['clean fda company name','clean ndc row', 'clean ndc company', 'original ndc company', 'fuzz ratio']]

# %%
dnf_match_unique.to_csv('../data/working/fda_dna_matching.csv')
